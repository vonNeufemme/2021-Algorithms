# %% [markdown]
# # 3.5 Stacks
#
# - Behave like real-world stacks
#   - LIFO (last in, first out)
# - like stacking a deck of cards:
#   - Put (`push`) one card on table
#   - Stack (`push`) another on top, then `push` a third.
#   - To access cards, top card is retrieved(`pop`ped) first.
#   - Last to pop is card placed on table first.
# - `push` and `pop`: both $O(1)$

# %%
sticky_notes(notes1, fontFace=cv2.FONT_HERSHEY_SIMPLEX, fontScale=0.475)
# Out:
# <style> pre { white-space: pre-wrap; } </style>
# <style> pre { white-space: pre-wrap; } </style>
# <PIL.Image.Image image mode=RGB size=476x248 at 0x7F4BBC5FC3D0>

# %%
show_img("/content/here/MyDrive/Data and Algorithms/ALGO03/Lifo_stack.png", resize=0.75, source="Wikipedia")
# Out:
# <style> pre { white-space: pre-wrap; } </style>
# <style> pre { white-space: pre-wrap; } </style>
# <PIL.Image.Image image mode=RGB size=580x405 at 0x7F4BB8FD8310>

# %% [markdown]
# ## Stack with lists

# %%
s = []
s
# Out:
# <style> pre { white-space: pre-wrap; } </style>
# <style> pre { white-space: pre-wrap; } </style>
# []

# %%
s.append('two of spades')  # push
s
# Out:
# <style> pre { white-space: pre-wrap; } </style>
# <style> pre { white-space: pre-wrap; } </style>
# ['two of spades']

# %%
s.append("queen of hearts")
s
# Out:
# <style> pre { white-space: pre-wrap; } </style>
# <style> pre { white-space: pre-wrap; } </style>
# ['two of spades', 'queen of hearts']

# %%
s.append("ace of clubs")
s.append("king of hearts")
s
# Out:
# <style> pre { white-space: pre-wrap; } </style>
# <style> pre { white-space: pre-wrap; } </style>
# ['two of spades', 'queen of hearts', 'ace of clubs', 'king of hearts']

# %%
s.pop()
s
# Out:
# <style> pre { white-space: pre-wrap; } </style>
# <style> pre { white-space: pre-wrap; } </style>
# ['two of spades', 'queen of hearts', 'ace of clubs']

# %% [markdown]
# # 3.6 Queues
#
# - Behave like real-world queue.
#   - FIFO: First in, first out
# - Head: first/oldest element
# - Tail: last/newest
# - Enqueue: add element to tail
# - Dequeue: remove element from head
# - Peek: access head element but leave it in queue (show me your id!)
#
# **Useful resources**
# jonkrohn https://github.com/jonkrohn/DLTFpT/blob/master/notebooks/cartpole_dqn.ipynb
# Keon https://github.com/keon/deep-q-learning/blob/master/dqn.py

# %%
show_img("/content/here/MyDrive/Data and Algorithms/ALGO03/queue.png", source="Wikipedia")
# Out:
# <style> pre { white-space: pre-wrap; } </style>
# <style> pre { white-space: pre-wrap; } </style>
# <PIL.Image.Image image mode=RGB size=402x267 at 0x7F4BB90A2710>

# %% [markdown]
# # 3.7 Deques
# (Double-ended queue)
#
# - Builds upon the idea of queue.
# - Double-ended queue
# - Can enqueue or dequeue from $either$ end.
#   - Stack (enqueue and dequeue from the same end)
#   - or queue (enqueue and dequeue from opposing ends)

# %% [markdown]
# References
#
# My algorithm learning notebook following the live lesson series [**"Data Structures, Algorithms, and Machine Learning Optimization"**](https://learning.oreilly.com/videos/data-structures-algorithms/9780137644889/) by Dr. Jon Krohn. I adapted some and partially modified or added entirely new code. Notes largely based on and (some of them entirely) from Jon's notebooks and learning materials. The lesson and original notebook source code at:
#
# https://learning.oreilly.com/videos/data-structures-algorithms/9780137644889/
# https://github.com/jonkrohn/ML-foundations/blob/master/notebooks/7-algos-and-data-structures.ipynb
